# %% [markdown]
# # everywhereml.classification.sklearn.linear_model.LogisticRegression
#
# See [sklearn.linear_model.LogisticRegression](http://scikit-learn.org/stable/modules/linear_model/LogisticRegression.html).

# %%
import sys
sys.path.append('../../../../')

from everywhereml.classification.sklearn.linear_model import LogisticRegression
from everywhereml.data.plot import scatter
from sklearn.datasets import load_iris

# %%
"""
Load Iris
"""
X, y = load_iris(return_X_y=True)

scatter(X, hue=y, title='Original')
scatter(X, hue=y, tsne=2, title='Original (t-SNE)')

# %%
"""
Classify
"""
clf = LogisticRegression()
clf.fit(X, y)
y_pred = clf.predict(X)

scatter(X, hue=y_pred, title='Predicted')
scatter(X, hue=y_pred, tsne=2, title='Predicted (t-SNE)')
# Out:
# /Users/simone/PycharmProjects/everywhereml/venv/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
"""
Confusion matrix
"""
clf.plot_confusion_matrix(X, y)

# %%
"""
Classification errors
"""
scatter(X, hue=(y == y_pred), title='Classification errors')
scatter(X, hue=(y == y_pred), tsne=2, title='Classification errors (t-SNE)')

# %%
"""
Port to C++
"""
print(clf.port(language='cpp'))
# Out:
# #ifndef
# #define
# #include <cstdarg>
#
# namespace EverywhereML {
#     namespace Classification {
#         class LogisticRegression {
#             public:
#
#                 /**
#                  * Predict class from features
#                  */
#                 int predict(float *x) {
#
#     float votes[3] = { 0.0f };
#
#
#         votes[0] = dot(x, -0.418740267, 0.966992736, -2.521028317, -1.084165994);
#
#         votes[1] = dot(x, 0.531230439, -0.314733646, -0.200023946, -0.948660818);
#
#         votes[2] = dot(x, -0.112490172, -0.652259090, 2.721052263, 2.032826812);
#
#
#     // return argmax of votes
# uint8_t classIdx = 0;
# float maxVotes = votes[0];
#
# for (uint8_t i = 1; i < 3; i++) {
#     if (votes[i] > maxVotes) {
#         classIdx = i;
#         maxVotes = votes[i];
#     }
# }
#
# return classIdx;
#
#                 }
#
#
#
#             protected:
#
#
#     /**
#  * Compute dot product
#  */
# float dot(float *x, ...) {
#     va_list w;
# ...

# %%
"""
Port to JS
"""
print(clf.port(language='js'))
# Out:
# function LogisticRegression() {
#
#
#     /**
#      * Predict class index
#      *
#      * @return int
#      */
#     this.predict = function(x) {
#         var $this = this;
#
#
#     let votes = [0.000000000, 0.000000000, 0.000000000];
#
#
#         votes[0] = this.dot(x, [-0.418740267, 0.966992736, -2.521028317, -1.084165994]);
#
#         votes[1] = this.dot(x, [0.531230439, -0.314733646, -0.200023946, -0.948660818]);
#
#         votes[2] = this.dot(x, [-0.112490172, -0.652259090, 2.721052263, 2.032826812]);
#
#
#     // return argmax of votes
# let classIdx = 0;
# let maxVotes = votes[0];
#
# for (let i = 1; i < 3; i++) {
#     if (votes[i] > maxVotes) {
#         classIdx = i;
#         maxVotes = votes[i];
#     }
# }
#
# return classIdx;
#
#     }
#
#
#
#
#     /**
#  * Compute dot product between two vectors
#  *
#  */
# this.dot(a, b) {
#     return a.reduce(function(dot, ai, i) {
#         return dot + (ai * b[i]);
#     });
# }
#
#
# };

# %%
"""
Port to PHP
"""
print(clf.port(language='php'))
# Out:
# <?php
#
# namespace EverywhereML\Classification\Sklearn\Linear_model;
#
#
# /**
#  * Classifier ported from EverywhereML
#  */
# class LogisticRegression {
#     /**
#      * Predict class from features
#      * @param $x array
#      * @return int
#      */
#     public function predict(array $x) : int {
#
#     $votes = [0.000000000, 0.000000000, 0.000000000];
#
#
#         $votes[0] = $this->dot($x, [-0.418740267, 0.966992736, -2.521028317, -1.084165994]);
#
#         $votes[1] = $this->dot($x, [0.531230439, -0.314733646, -0.200023946, -0.948660818]);
#
#         $votes[2] = $this->dot($x, [-0.112490172, -0.652259090, 2.721052263, 2.032826812]);
#
#
#     // return argmax of votes
# $classIdx = 0;
# $maxVotes = $votes[0];
#
# for ($i = 1; $i < 3; $i++) {
#     if ($votes[$i] > $maxVotes) {
#         $classIdx = $i;
#         $maxVotes = $votes[$i];
#     }
# }
#
# return $classIdx;
#
#     }
#
#
#
#
#     /**
#  * Compute dot product
#  * @param $a array
#  * @param $b array
# ...
