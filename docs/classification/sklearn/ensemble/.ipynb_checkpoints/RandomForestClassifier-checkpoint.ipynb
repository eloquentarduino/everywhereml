# %% [markdown]
# # everywhereml.classification.sklearn.ensemble.RandomForestClassifier
#
# See [sklearn.ensemble.RandomForestClassifier](http://scikit-learn.org/stable/modules/ensemble.html).

# %%
import sys
sys.path.append('../../../../')

from everywhereml.classification.sklearn.ensemble import RandomForestClassifier
from everywhereml.data.plot import scatter
from sklearn.datasets import load_iris

# %%
"""
Load Iris
"""
X, y = load_iris(return_X_y=True)

scatter(X, hue=y, title='Original')
scatter(X, hue=y, tsne=2, title='Original (t-SNE)')

# %%
"""
Classify
"""
clf = RandomForestClassifier(n_estimators=10, max_depth=5)
clf.fit(X, y)
y_pred = clf.predict(X)

scatter(X, hue=y_pred, title='Predicted')
scatter(X, hue=y_pred, tsne=2, title='Predicted (t-SNE)')

# %%
"""
Confusion matrix
"""
clf.plot_confusion_matrix(X, y)

# %%
"""
Classification errors
"""
scatter(X, hue=(y == y_pred), title='Classification errors')
scatter(X, hue=(y == y_pred), tsne=2, title='Classification errors (t-SNE)')

# %%
"""
Port to C++
"""
print(clf.port(language='cpp'))
# Out:
# #ifndef UUID4940136800
# #define UUID4940136800
# #include <cstdarg>
#
# namespace EverywhereML {
#     namespace Classification {
#         class RandomForestClassifier {
#             public:
#
#                 /**
#                  * Predict class from features
#                  */
#                 int predict(float *x) {
#
#     uint16_t votes[3] = { 0 };
#
#
#         votes[tree0()] += 1;
#
#         votes[tree1()] += 1;
#
#         votes[tree2()] += 1;
#
#         votes[tree3()] += 1;
#
#         votes[tree4()] += 1;
#
#         votes[tree5()] += 1;
#
#         votes[tree6()] += 1;
#
#         votes[tree7()] += 1;
#
#         votes[tree8()] += 1;
#
#         votes[tree9()] += 1;
#
#
#     // return argmax of votes
# uint8_t classIdx = 0;
# float maxVotes = votes[0];
#
# for (uint8_t i = 1; i < 3; i++) {
#     if (votes[i] > maxVotes) {
#         classIdx = i;
#         maxVotes = votes[i];
#     }
# }
#
# return classIdx;
#
#                 }
#
#
#
#             protected:
#
#
#
#
#
#             /**
#              * Random forest's tree #0
#              * @return predicted class
#              */
#             uint16_t tree0() {
#
#     if (x[2] <= 2.449999988079071) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 7.0) {
#
#
#     if (x[3] <= 1.3499999642372131) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.799999952316284) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #1
#              * @return predicted class
#              */
#             uint16_t tree1() {
#
#     if (x[3] <= 0.75) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #2
#              * @return predicted class
#              */
#             uint16_t tree2() {
#
#     if (x[0] <= 5.549999952316284) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.75) {
#
#
#     if (x[1] <= 3.600000023841858) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 0;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.699999988079071) {
#
#
#     if (x[2] <= 5.349999904632568) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #3
#              * @return predicted class
#              */
#             uint16_t tree3() {
#
#     if (x[3] <= 0.75) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 7.099999904632568) {
#
#
#     if (x[3] <= 1.3499999642372131) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     if (x[1] <= 2.850000023841858) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.950000047683716) {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[2] <= 4.650000095367432) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #4
#              * @return predicted class
#              */
#             uint16_t tree4() {
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.25) {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[2] <= 5.1499998569488525) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[1] <= 3.100000023841858) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[2] <= 4.799999952316284) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.6000001430511475) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #5
#              * @return predicted class
#              */
#             uint16_t tree5() {
#
#     if (x[0] <= 5.549999952316284) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 4.950000047683716) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.699999988079071) {
#
#
#     if (x[3] <= 0.7000000029802322) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[1] <= 2.25) {
#
#
#     if (x[3] <= 1.25) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[0] <= 5.950000047683716) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #6
#              * @return predicted class
#              */
#             uint16_t tree6() {
#
#     if (x[0] <= 5.8500001430511475) {
#
#
#     if (x[2] <= 2.449999988079071) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #7
#              * @return predicted class
#              */
#             uint16_t tree7() {
#
#     if (x[2] <= 2.599999964237213) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.8500001430511475) {
#
#
#     if (x[2] <= 4.700000047683716) {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[2] <= 4.75) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.550000190734863) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     if (x[1] <= 2.850000023841858) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #8
#              * @return predicted class
#              */
#             uint16_t tree8() {
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 2.5) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[0] <= 4.950000047683716) {
#
#
#     if (x[2] <= 3.899999976158142) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.550000011920929) {
#
#
#     return 2;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#             }
#
#
#
#             /**
#              * Random forest's tree #9
#              * @return predicted class
#              */
#             uint16_t tree9() {
#
#     if (x[0] <= 5.450000047683716) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     return 0;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[1] <= 3.700000047683716) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 0;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[1] <= 2.75) {
#
#
#     if (x[3] <= 1.550000011920929) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     return 1;
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     return 2;
#
#
#     }
#
#
#     }
#
#
#     }
#
#             }
#
#
#
#
#         };
#     }
# }
#
# #endif

# %%
"""
Port to JS
"""
print(clf.port(language='js'))
# Out:
# function RandomForestClassifier() {
#
#
#     /**
#      * Predict class index
#      *
#      * @return int
#      */
#     this.predict = function(x) {
#         var $this = this;
#
#
#     let votes = [0.000000000, 0.000000000, 0.000000000];
#
#
#
#             // tree #1
#
#     if (x[2] <= 2.449999988079071) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 7.0) {
#
#
#     if (x[3] <= 1.3499999642372131) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.799999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #2
#
#     if (x[3] <= 0.75) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #3
#
#     if (x[0] <= 5.549999952316284) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.75) {
#
#
#     if (x[1] <= 3.600000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[0] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.699999988079071) {
#
#
#     if (x[2] <= 5.349999904632568) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #4
#
#     if (x[3] <= 0.75) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 7.099999904632568) {
#
#
#     if (x[3] <= 1.3499999642372131) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[1] <= 2.850000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.950000047683716) {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[2] <= 4.650000095367432) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #5
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.25) {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[2] <= 5.1499998569488525) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[1] <= 3.100000023841858) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[2] <= 4.799999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.6000001430511475) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #6
#
#     if (x[0] <= 5.549999952316284) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 4.950000047683716) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.699999988079071) {
#
#
#     if (x[3] <= 0.7000000029802322) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[1] <= 2.25) {
#
#
#     if (x[3] <= 1.25) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[0] <= 5.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #7
#
#     if (x[0] <= 5.8500001430511475) {
#
#
#     if (x[2] <= 2.449999988079071) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #8
#
#     if (x[2] <= 2.599999964237213) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.8500001430511475) {
#
#
#     if (x[2] <= 4.700000047683716) {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[2] <= 4.75) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.550000190734863) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     if (x[1] <= 2.850000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #9
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 2.5) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[0] <= 4.950000047683716) {
#
#
#     if (x[2] <= 3.899999976158142) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.550000011920929) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#
#
#             // tree #10
#
#     if (x[0] <= 5.450000047683716) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[1] <= 3.700000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[0] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[1] <= 2.75) {
#
#
#     if (x[3] <= 1.550000011920929) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#     // return argmax of votes
# let classIdx = 0;
# let maxVotes = votes[0];
#
# for (let i = 1; i < 3; i++) {
#     if (votes[i] > maxVotes) {
#         classIdx = i;
#         maxVotes = votes[i];
#     }
# }
#
# return classIdx;
#
#     }
#
#
#
#
#
# };

# %%
"""
Port to PHP
"""
print(clf.port(language='php'))
# Out:
# <?php
#
# namespace EverywhereML\Classification\Sklearn\Ensemble;
#
#
# /**
#  * Classifier ported from EverywhereML
#  */
# class RandomForestClassifier {
#     /**
#      * Predict class from features
#      * @param $x array
#      * @return int
#      */
#     public function predict(array $x) : int {
#
#     $votes = [0.000000000, 0.000000000, 0.000000000];
#
#
#
#             // tree #1
#
#     if (x[2] <= 2.449999988079071) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 7.0) {
#
#
#     if (x[3] <= 1.3499999642372131) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.799999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #2
#
#     if (x[3] <= 0.75) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #3
#
#     if (x[0] <= 5.549999952316284) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.75) {
#
#
#     if (x[1] <= 3.600000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[0] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.699999988079071) {
#
#
#     if (x[2] <= 5.349999904632568) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #4
#
#     if (x[3] <= 0.75) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[0] <= 7.099999904632568) {
#
#
#     if (x[3] <= 1.3499999642372131) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[1] <= 2.850000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.950000047683716) {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[2] <= 4.650000095367432) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #5
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.25) {
#
#
#     if (x[3] <= 1.6500000357627869) {
#
#
#     if (x[2] <= 5.1499998569488525) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[1] <= 3.100000023841858) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[2] <= 4.799999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.6000001430511475) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #6
#
#     if (x[0] <= 5.549999952316284) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 4.950000047683716) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.699999988079071) {
#
#
#     if (x[3] <= 0.7000000029802322) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[1] <= 2.25) {
#
#
#     if (x[3] <= 1.25) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[0] <= 5.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #7
#
#     if (x[0] <= 5.8500001430511475) {
#
#
#     if (x[2] <= 2.449999988079071) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #8
#
#     if (x[2] <= 2.599999964237213) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 5.8500001430511475) {
#
#
#     if (x[2] <= 4.700000047683716) {
#
#
#     if (x[3] <= 1.600000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[2] <= 4.75) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.550000190734863) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[0] <= 6.049999952316284) {
#
#
#     if (x[1] <= 2.850000023841858) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#             // tree #9
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[2] <= 2.5) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.950000047683716) {
#
#
#     if (x[0] <= 4.950000047683716) {
#
#
#     if (x[2] <= 3.899999976158142) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.550000011920929) {
#
#
#     votes[2] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#
#
#             // tree #10
#
#     if (x[0] <= 5.450000047683716) {
#
#
#     if (x[3] <= 0.800000011920929) {
#
#
#     votes[0] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 4.8500001430511475) {
#
#
#     if (x[1] <= 3.700000047683716) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[0] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[3] <= 1.75) {
#
#
#     if (x[1] <= 2.75) {
#
#
#     if (x[3] <= 1.550000011920929) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[1] += 1;
#
#
#     }
#
#
#     }
#     else {
#
#
#     if (x[2] <= 5.049999952316284) {
#
#
#     votes[1] += 1;
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#     else {
#
#
#     votes[2] += 1;
#
#
#     }
#
#
#     }
#
#
#     }
#
#
#
#
#     // return argmax of votes
# $classIdx = 0;
# $maxVotes = $votes[0];
#
# for ($i = 1; $i < 3; $i++) {
#     if ($votes[$i] > $maxVotes) {
#         $classIdx = $i;
#         $maxVotes = $votes[$i];
#     }
# }
#
# return $classIdx;
#
#     }
#
#
#
#
# }
