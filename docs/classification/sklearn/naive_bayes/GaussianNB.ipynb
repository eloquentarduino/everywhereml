# %% [markdown]
# # everywhereml.classification.sklearn.naive_bayes.GaussianNB
#
# See [sklearn.naive_bayes.GaussianNB](http://scikit-learn.org/stable/modules/naive_bayes/GaussianNB.html).

# %%
import sys
sys.path.append('../../../../')

from everywhereml.classification.sklearn.naive_bayes import GaussianNB
from everywhereml.data.plot import scatter
from sklearn.datasets import load_iris

# %%
"""
Load Iris
"""
X, y = load_iris(return_X_y=True)

scatter(X, hue=y, title='Original')
scatter(X, hue=y, tsne=2, title='Original (t-SNE)')

# %%
"""
Classify
"""
clf = GaussianNB()
clf.fit(X, y)
y_pred = clf.predict(X)

scatter(X, hue=y_pred, title='Predicted')
scatter(X, hue=y_pred, tsne=2, title='Predicted (t-SNE)')

# %%
"""
Confusion matrix
"""
clf.plot_confusion_matrix(X, y)

# %%
"""
Classification errors
"""
scatter(X, hue=(y == y_pred), title='Classification errors')
scatter(X, hue=(y == y_pred), tsne=2, title='Classification errors (t-SNE)')

# %%
"""
Port to C++
"""
print(clf.port(language='cpp'))
# Out:
# #ifndef
# #define
# #include <cstdarg>
#
# namespace EverywhereML {
#     namespace Classification {
#         class GaussianNB {
#             public:
#
#                 /**
#                  * Predict class from features
#                  */
#                 int predict(float *x) {
#
#     float votes[3] = {2.711529836, 0.894256348, 0.169048726};
#
#
#         {
#             uint16_t k = 0;
#
#
#                 // chunk from 0 to 4
#                 votes[0] -= 0.5 * sum(x + k, 4,  5.006f, 8.212607787f, 3.428f, 7.101465586f, 1.462f, 33.834074139f, 0.246f, 91.877959904f);
#
#         }
#
#         {
#             uint16_t k = 0;
#
#
#                 // chunk from 0 to 4
#                 votes[1] -= 0.5 * sum(x + k, 4,  5.936f, 3.829891492f, 2.77f, 10.362693968f, 4.26f, 4.621072023f, 1.326f, 26.093307568f);
#
#         }
#
#         {
#             uint16_t k = 0;
#
#
#                 // chunk from 0 to 4
#                 votes[2] -= 0.5 * sum(x + k, 4,  6.588f, 2.523621074f, 2.974f, 9.8112316f, 5.552f, 3.35012861f, 2.026f, 13.527405959f);
#
#         }
#
#
#     // return argmax of votes
# uint8_t classIdx = 0;
# float maxVotes = votes[0];
#
# for (uint8_t i = 1; i < 3; i++) {
#     if (votes[i] > maxVotes) {
#         classIdx = i;
#         maxVotes = votes[i];
#     }
# }
#
# return classIdx;
#
#                 }
#
#
#
#             protected:
#
#
#
#      /**
#      * Sum2
#      */
#      float sum(float *x, uint16_t count, ...) {
#         va_list w;
#         va_start(w, count);
#         float sum = 0.0f;
#
#         for (uint16_t i = 0; i < count; i++) {
#             sum += pow(x[i] - va_arg(w, double), 2) * va_arg(w, double);
#         }
#
#         return sum;
#      }
#
#
#         };
#     }
# }
#
# #endif

# %%
"""
Port to JS
"""
print(clf.port(language='js'))
# Out:
# function GaussianNB() {
#
#
#     /**
#      * Predict class index
#      *
#      * @return int
#      */
#     this.predict = function(x) {
#         var $this = this;
#
#
#     let votes = [2.711529836, 0.894256348, 0.169048726];
#
#
#         votes[0] -= 0.5 * this.joint_log_likelihood(x, [5.006000000, 3.428000000, 1.462000000, 0.246000000], [8.212607787, 7.101465586, 33.834074139, 91.877959904]);
#
#         votes[1] -= 0.5 * this.joint_log_likelihood(x, [5.936000000, 2.770000000, 4.260000000, 1.326000000], [3.829891492, 10.362693968, 4.621072023, 26.093307568]);
#
#         votes[2] -= 0.5 * this.joint_log_likelihood(x, [6.588000000, 2.974000000, 5.552000000, 2.026000000], [2.523621074, 9.811231600, 3.350128610, 13.527405959]);
#
#
#     // return argmax of votes
# let classIdx = 0;
# let maxVotes = votes[0];
#
# for (let i = 1; i < 3; i++) {
#     if (votes[i] > maxVotes) {
#         classIdx = i;
#         maxVotes = votes[i];
#     }
# }
#
# return classIdx;
#
#     }
#
#
#
#
#
#      /**
#       * Compute joint log likelihood
#       */
#      this.joint_log_likelihood(x, theta, invSigma) {
#         return x.reduce(function(likelihood, x, i) {
#             return likelihood + Math.pow(x - theta[i], 2) * invSigma[i];
#         }, 0);
#      }
#
#
#
# };

# %%
"""
Port to PHP
"""
print(clf.port(language='php'))
# Out:
# <?php
#
# namespace EverywhereML\Classification\Sklearn\Naive_bayes;
#
#
# /**
#  * Classifier ported from EverywhereML
#  */
# class GaussianNB {
#     /**
#      * Predict class from features
#      * @param $x array
#      * @return int
#      */
#     public function predict(array $x) : int {
#
#     $votes = [2.711529836, 0.894256348, 0.169048726];
#
#
#         $votes[0] -= 0.5 * $this->joint_log_likelihood($x, [5.006000000, 3.428000000, 1.462000000, 0.246000000], [8.212607787, 7.101465586, 33.834074139, 91.877959904]);
#
#         $votes[1] -= 0.5 * $this->joint_log_likelihood($x, [5.936000000, 2.770000000, 4.260000000, 1.326000000], [3.829891492, 10.362693968, 4.621072023, 26.093307568]);
#
#         $votes[2] -= 0.5 * $this->joint_log_likelihood($x, [6.588000000, 2.974000000, 5.552000000, 2.026000000], [2.523621074, 9.811231600, 3.350128610, 13.527405959]);
#
#
#     // return argmax of votes
# $classIdx = 0;
# $maxVotes = $votes[0];
#
# for ($i = 1; $i < 3; $i++) {
#     if ($votes[$i] > $maxVotes) {
#         $classIdx = $i;
#         $maxVotes = $votes[$i];
#     }
# }
#
# return $classIdx;
#
#     }
#
#
#
#
#
#      /**
#       * Compute joint log likelihood
#       * @param $x array
#       * @param $theta array
#       * @param $invSigma array
#       * @return float
#       */
#      protected function joint_log_likelihood($x, $theta, $invSigma) : float {
#         return array_reduce($x, function($likelihood, $x, $i) use ($theta, $invSigma) {
#             return $likelihood + pow($x - $theta[$i], 2) * $invSigma[$i];
#         }, 0);
#      }
#
#
# }
